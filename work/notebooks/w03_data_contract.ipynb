# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fidashka07/FlyRank-AI-Ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# ## Unit of analysis + time window
#
# One row represents the daily search performance of one content page for one client.
#
# Time window:
# March 2026 (2026-03).
# I use this month because it is a mid-panel month and avoids using the final month for model development.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
con.sql(f"""
SELECT
COUNT(*) AS total_rows,
MIN(report_date) AS start_date,
MAX(report_date) AS end_date
FROM {TABLES['fact_daily']}
WHERE month='2026-03'
""").df()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_594/1648647598.py in <cell line: 0>()
#       1 # This cell is for CODE (numbers, a query, a check).
#       2 # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# ----> 3 con.sql(f"""
#       4 SELECT
#       5 COUNT(*) AS total_rows,
#
# NameError: name 'con' is not defined

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
## Features
- gsc_impressions
- gsc_clicks
- gsc_avg_position
- visible_queries
- rare_share

## Label
Whether impressions decline by more than 20% in the following period.

## Context
- client_hash_id
- content_hash_id
- report_date

## Excluded
Client names, URLs and any future information are excluded to avoid data leakage and protect privacy.
# Out:
#   File "/tmp/ipykernel_594/4257835890.py", line 9
#     Whether impressions decline by more than 20% in the following period.
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
# Query 1
con.sql(f"""
SELECT COUNT(*) AS total_rows
FROM {TABLES['fact_daily']}
WHERE month='2026-03'
""").df()
# Query 2
con.sql(f"""
SELECT
MIN(report_date),
MAX(report_date)
FROM {TABLES['fact_daily']}
WHERE month='2026-03'
""").df()
# Query 3
con.sql(f"""
SELECT
COUNT(*)
FROM {TABLES['fact_daily']}
WHERE is_available IS TRUE
AND month='2026-03'
""").df()

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
## Data limitations

The dataset does not contain client names or page URLs.
Some clients have shorter history than others, creating an unbalanced panel.
The data shows search performance only and cannot explain the business reasons behind changes.
The model should be used for decision support, not as proof of causation.
# Out:
#   File "/tmp/ipykernel_594/384402601.py", line 3
#     The dataset does not contain client names or page URLs.
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
